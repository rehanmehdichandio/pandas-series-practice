# %% [markdown]
# <a href="https://colab.research.google.com/github/rehanmehdichandio/pandas-practice/blob/main/pandas_series_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Pandas</h1>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Series From List**

# %%
#Sting
country = ['Pakistan', 'India', 'USA','Nepal', 'Srilanka']

pd.Series(country)
# Out:
# 0    Pakistan
# 1       India
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
#interger
runs = [13,14,58,90]

pd.Series(runs)
# Out:
# 0    13
# 1    14
# 2    58
# 3    90
# dtype: int64

# %%
#custom_index
marks = [76,89,19,33,70]
subjects = ['maths', 'English', 'JavScript', 'Physics', 'python']

pd.Series(marks , subjects)
# Out:
# maths        76
# English      89
# JavScript    19
# Physics      33
# python       70
# dtype: int64

# %%
  result = pd.Series(marks , subjects, name='Rehan ke Marks')

# %%
result
# Out:
# maths        76
# English      89
# JavScript    19
# Physics      33
# python       70
# Name: Rehan ke Marks, dtype: int64

# %%
marks_dict = {
    'English' : 67,
    'Maths' : 78,
    'Physics' : 89
}

marks_dict_series = pd.Series(marks_dict, name = 'Rehan ki Marks')

# %%
marks_dict_series
# Out:
# English    67
# Maths      78
# Physics    89
# Name: Rehan ki Marks, dtype: int64

# %% [markdown]
# **Series Attributes**

# %%
#Size
marks_dict_series.size
# Out:
# 3

# %%
#dtype
marks_dict_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_dict_series.name
# Out:
# 'Rehan ki Marks'

# %%
#is_unique IF ALL UNIQUE RETURN TRUE ELSE RETURNS FALLS
marks_dict_series.is_unique
# Out:
# True

# %%
#index
marks_dict_series.index
# Out:
# Index(['English', 'Maths', 'Physics'], dtype='object')

# %%
#value
marks_dict_series.values
# Out:
# array([67, 78, 89])

# %% [markdown]
# **Series Using read_csv**

# %%
# with one col
df = pd.read_csv('/content/subs.csv')
df.squeeze(axis=0)
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')
vk.squeeze(axis=0)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
bol = pd.read_csv('/content/bollywood.csv', index_col='movie')
bol.squeeze(axis=0)
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
bol
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# Series **Methods**

# %%
#head and tail
df.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
vk.head(3)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13

# %%
vk.tail(5)
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
#sample   randomly selected data
bol.sample(5)
# Out:
#                                    lead
# movie
# Jabariya Jodi         Sidharth Malhotra
# Tulsi (film)            Manisha Koirala
# Fever (2016 film)     Rajeev Khandelwal
# Ek Hasina Thi (film)      Saif Ali Khan
# Aisa Yeh Jahaan          Yashpal Sharma

# %%
#value_counts --> movies
bol.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
#sort_values(by='parameter')
vk.sort_values(by='runs',ascending=False)
# Out:
#           runs
# match_no
# 128        113
# 126        109
# 123        108
# 164        100
# 120        100
# ...        ...
# 93           0
# 211          0
# 130          0
# 8            0
# 135          0
#
# [215 rows x 1 columns]

# %%
vk.sort_values(by='runs', ascending=False).head(1).values
# Out:
# array([[113]])

# %%
vk.sort_values(by='runs', ascending=False).head(1).values[0]
# Out:
# array([113])

# %%
vk.sort_values(by='runs', inplace=True)

# %%
vk
# Out:
#           runs
# match_no
# 87           0
# 211          0
# 207          0
# 206          0
# 91           0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
#sort_index --> inplace --> movies

bol.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
#  **Series Maths Maths Method**

# %%
#count
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
#sum --> product
vk.sum()
# Out:
# runs    6634
# dtype: int64

# %%
vk.product()
# Out:
# runs    0
# dtype: int64

# %%
#mean, mode, median, std, var
print(vk.mean())
print(vk.median())
print(bol.mode())
print(vk.std())
print(vk.var())
# Out:
# runs    30.855814
# dtype: float64
# runs    24.0
# dtype: float64
#            lead
# 0  Akshay Kumar
# runs    26.229801
# dtype: float64
# runs    688.002478
# dtype: float64

# %%
#min    #max
print(vk.min())
print(vk.max())
# Out:
# runs    0
# dtype: int64
# runs    113
# dtype: int64

# %%
#describe
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
df.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %% [markdown]
# **Series Indexing**

# %%
x = pd.Series([1,2,3,4,5,6,7,8,9])
x[1]  #negative indexing doesn't work
# Out:
# 2

# %%
#slicing
vk[5:60]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2
# 17          22
# 18          19
# 19          16
# 20          15
# 21          20
# 22          38
# 23          19
# 24          24
# 25           7
# 26           2
# 27          16
# 28          17
# 29          24
# 30          38
# 31          34
# 32          42
# 33          13
# 34          58
# 35           3
# 36          14
# 37          37
# 38           9
# 39          23
# 40          12
# 41          71
# 42          35
# 43          30
# 44          56
# 45          67
# 46          27
# 47          27
# 48          39
# 49          15
# 50          11
# 51          31
# 52          70
# 53           8
# 54          35
# 55           8
# 56           6
# 57          57
# 58          22
# 59          16
# 60           4

# %%
#negative slicing
vk[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
bol[-5:]
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
#fancy indexing
x[[1,3,4,5]]
# Out:
# 1    2
# 3    4
# 4    5
# 5    6
# dtype: int64

# %%
result
# Out:
# maths        76
# English      89
# JavScript    19
# Physics      33
# python       70
# Name: Rehan ke Marks, dtype: int64

# %%
result['sst']=90

# %%
result
# Out:
# maths        76
# English      89
# JavScript    19
# Physics      33
# python       70
# sst          90
# Name: Rehan ke Marks, dtype: int64

# %%
#slicing
runs
# Out:
# [13, 14, 58, 90]

# %%
runs[1:3]=[100,100]

# %%
runs
# Out:
# [13, 100, 100, 90]

# %%
 print(len(df))
 print(type(df))
 print(dir(df))
 print(sorted(df))
 print(min(df))
 print(max(df))

#  print(df.min())
#  print(df.max())
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
'Turmila Matondkar' in vk
# Out:
# False

# %%
#looping

for i in bol.values:
  print(i)
# Out:
# ['Vicky Kaushal']
# ['Vicky Ahuja']
# ['Anupam Kher']
# ['Emraan Hashmi']
# ['Mona Ambegaonkar']
# ['Geetika Vidya Ohlyan']
# ['Arshad Warsi']
# ['Radhika Apte']
# ['Kangana Ranaut']
# ['Nawazuddin Siddiqui']
# ['Ali Asgar']
# ['Ranveer Singh']
# ['Prit Kamani']
# ['Ajay Devgn']
# ['Sushant Singh Rajput']
# ['Amitabh Bachchan']
# ['Abhimanyu Dasani']
# ['Talha Arshad Reshi']
# ['Nawazuddin Siddiqui']
# ['Garima Agarwal']
# ['Rasika Agashe']
# ['Barun Sobti']
# ['Akshay Kumar']
# ['Zaheer Iqbal']
# ['Vidyut Jammwal']
# ['Deepika Amin']
# ['Manav Kaul']
# ['Naseeruddin Shah']
# ['Varun Dhawan']
# ['Shreyas Talpade']
# ['Tiger Shroff']
# ['Boman Irani']
# ['Ajay Devgn']
# ['Arjun Kapoor']
# ['Gavie Chahal']
# ['Prabhu Deva']
# ['Shahid Kapoor']
# ['Ayushmann Khurrana']
# ['Anupam Kher']
# ['Karanvir Bohra']
# ['Hrithik Roshan']
# ['Jimmy Sheirgill']
# ['John Abraham']
# ['Rishi Kapoor']
# ['Kangana Ranaut']
# ['Natalia Janoszek']
# ['Diljit Dosanjh']
# ['Sidharth Malhotra']
# ...

# %%
#Arithmatic Operator(broadcasting)
result
# Out:
# maths        76
# English      89
# JavScript    19
# Physics      33
# python       70
# sst          90
# Name: Rehan ke Marks, dtype: int64

# %%
100-result
# Out:
# maths        24
# English      11
# JavScript    81
# Physics      67
# python       30
# sst          10
# Name: Rehan ke Marks, dtype: int64

# %%
#Relational Operator:
vk >= 50
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %%
vk[vk>=50].size
# Out:
# 215

# %%
df[df>200].size
# Out:
# 365

# %%
df.plot()
# Out:
# <Axes: >

# %%
bol.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>
